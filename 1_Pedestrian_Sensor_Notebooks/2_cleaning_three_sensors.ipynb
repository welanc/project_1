# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
# pulling the data from the csv file I created with 3 sensors
censors_df = pd.read_csv("../Output/1_pedestrian_csv/censors2019_chosen3.csv")
censors_df.head()
# Out:
#         Date  Hour  Bourke Street Mall (North)  Flinders St-Spark La  \
# 0  1/01/2019     0                         918                   802
# 1  1/01/2019     1                         995                   374
# 2  1/01/2019     2                         416                    98
# 3  1/01/2019     3                         382                    59
# 4  1/01/2019     4                         165                    10
#
#    QV Market-Elizabeth St (West)
# 0                            637
# 1                            719
# 2                            370
# 3                            256
# 4                            197

# %%
# Do all 3 sensors contain counts of -1?
print(censors_df['Bourke Street Mall (North)'].min())
print(censors_df['Flinders St-Spark La'].min())
print(censors_df['QV Market-Elizabeth St (West)'].min())
# Out:
# -1
# -1
# -1

# %%
censors_df.count()
# Out:
# Date                             8760
# Hour                             8760
# Bourke Street Mall (North)       8760
# Flinders St-Spark La             8760
# QV Market-Elizabeth St (West)    8760
# dtype: int64

# %%
censors_df.dtypes
# Out:
# Date                             object
# Hour                              int64
# Bourke Street Mall (North)        int64
# Flinders St-Spark La              int64
# QV Market-Elizabeth St (West)     int64
# dtype: object

# %%
# # Replacing any negative values with 0
# clean_df = censors_df.mask(censors_df['Bourke Street Mall (North)'] < 0, 0)
# clean_df = clean_df.mask(censors_df['Flinders St-Spark La'] < 0, 0)
# clean_df = clean_df.mask(censors_df['QV Market-Elizabeth St (West)'] < 0, 0)
# clean_df.head()

# %%
clean_df = censors_df.loc[(censors_df["Bourke Street Mall (North)"] != -1) & (censors_df["Flinders St-Spark La"] != -1) & 
                         (censors_df["QV Market-Elizabeth St (West)"] != -1),:]
clean_df.count()
# Out:
# Date                             8568
# Hour                             8568
# Bourke Street Mall (North)       8568
# Flinders St-Spark La             8568
# QV Market-Elizabeth St (West)    8568
# dtype: int64

# %%
# Checking min values for each location
print(clean_df['Bourke Street Mall (North)'].max())
print(clean_df['Bourke Street Mall (North)'].min())
print(clean_df['Flinders St-Spark La'].max())
print(clean_df['Flinders St-Spark La'].min())
print(clean_df['QV Market-Elizabeth St (West)'].max())
print(clean_df['QV Market-Elizabeth St (West)'].min())
# Out:
# 4896
# 2
# 3708
# 1
# 2957
# 13

# %%
clean_df.to_csv("../Output/1_pedestrian_csv/censors2019_chosen3_cleaned.csv", encoding="utf-8", index=False, header=True)

# %%
# grouping by the date and applying aggregates
average_daily = clean_df.groupby(["Date"])
average_daily = average_daily[['Bourke Street Mall (North)','Flinders St-Spark La', 'QV Market-Elizabeth St (West)']].mean()
average_daily.head()
# Out:
#            Bourke Street Mall (North)  Flinders St-Spark La  \
# Date
# 1/01/2019                 1119.375000            117.791667
# 1/02/2019                 1504.125000            185.708333
# 1/03/2019                 1458.750000            154.833333
# 1/04/2019                 1283.727273            138.818182
# 1/05/2019                 1384.791667            180.416667
#
#            QV Market-Elizabeth St (West)
# Date
# 1/01/2019                     363.500000
# 1/02/2019                     586.250000
# 1/03/2019                     551.000000
# 1/04/2019                     512.181818
# 1/05/2019                     588.875000

# %%
# Dropping the row of zero values, not sure why that's there?
average_daily = average_daily.drop(average_daily.index[0])
average_daily
# Out:
#            Bourke Street Mall (North)  Flinders St-Spark La  \
# Date
# 1/02/2019                 1504.125000            185.708333
# 1/03/2019                 1458.750000            154.833333
# 1/04/2019                 1283.727273            138.818182
# 1/05/2019                 1384.791667            180.416667
# 1/06/2019                 1442.583333            101.375000
# ...                               ...                   ...
# 9/08/2019                 1438.166667            138.791667
# 9/09/2019                 1133.666667            133.625000
# 9/10/2019                 1304.083333            146.083333
# 9/11/2019                 1299.125000            105.333333
# 9/12/2019                 1303.541667            135.250000
#
#            QV Market-Elizabeth St (West)
# Date
# 1/02/2019                     586.250000
# 1/03/2019                     551.000000
# 1/04/2019                     512.181818
# 1/05/2019                     588.875000
# 1/06/2019                     683.333333
# ...                                  ...
# 9/08/2019                     577.958333
# 9/09/2019                     383.375000
# 9/10/2019                     583.583333
# 9/11/2019                     633.041667
# 9/12/2019                     367.500000
#
# [362 rows x 3 columns]

# %%
average_daily.to_csv("../Output/1_pedestrian_csv/censors2019_chosen3_dailyaverage.csv", encoding="utf-8", index=False, header=True)

# %%
columns = average_daily.columns
print(columns)
# Out:
# Index(['Bourke Street Mall (North)', 'Flinders St-Spark La',
#        'QV Market-Elizabeth St (West)'],
#       dtype='object')

# %%
average_BSM = average_daily["Bourke Street Mall (North)"].mean()
average_BSM
# Out:
# 1356.9408589818781

# %%
average_flind = average_daily["Flinders St-Spark La"].mean()
average_flind
# Out:
# 147.0763476404691

# %%
average_QVM = average_daily["QV Market-Elizabeth St (West)"].mean()
average_QVM
# Out:
# 607.6168485280031

# %%
print(average_daily['Bourke Street Mall (North)'].min())
print(average_daily['Bourke Street Mall (North)'].max())
print(average_daily['Flinders St-Spark La'].min())
print(average_daily['Flinders St-Spark La'].max())
print(average_daily['QV Market-Elizabeth St (West)'].min())
print(average_daily['QV Market-Elizabeth St (West)'].max())
# Out:
# 132.0
# 2235.375
# 17.5
# 781.375
# 99.5
# 1087.7916666666667

# %%
# Transpose the data ready to merge to the Zomato data
average_transposed = average_daily.T
average_transposed
# Out:
# Date                             1/02/2019    1/03/2019    1/04/2019  \
# Bourke Street Mall (North)     1504.125000  1458.750000  1283.727273
# Flinders St-Spark La            185.708333   154.833333   138.818182
# QV Market-Elizabeth St (West)   586.250000   551.000000   512.181818
#
# Date                             1/05/2019    1/06/2019    1/07/2019  \
# Bourke Street Mall (North)     1384.791667  1442.583333  1296.041667
# Flinders St-Spark La            180.416667   101.375000   147.750000
# QV Market-Elizabeth St (West)   588.875000   683.333333   388.500000
#
# Date                             1/08/2019    1/09/2019    1/10/2019  \
# Bourke Street Mall (North)     1368.375000  1104.958333  1553.260870
# Flinders St-Spark La            143.000000    77.041667   162.478261
# QV Market-Elizabeth St (West)   632.958333   582.208333   655.913043
#
# Date                             1/11/2019  ...    9/03/2019    9/04/2019  \
# Bourke Street Mall (North)     1535.958333  ...  1546.083333  1355.375000
# Flinders St-Spark La            158.708333  ...   134.166667   181.666667
# QV Market-Elizabeth St (West)   639.375000  ...   769.000000   625.916667
#
# Date                             9/05/2019    9/06/2019    9/07/2019  \
# Bourke Street Mall (North)     1364.666667  1340.041667  1152.916667
# Flinders St-Spark La            148.958333   111.083333   184.291667
# QV Market-Elizabeth St (West)   581.208333   734.708333   703.958333
#
# Date                             9/08/2019    9/09/2019    9/10/2019  \
# Bourke Street Mall (North)     1438.166667  1133.666667  1304.083333
# Flinders St-Spark La            138.791667   133.625000   146.083333
# QV Market-Elizabeth St (West)   577.958333   383.375000   583.583333
#
# Date                             9/11/2019    9/12/2019
# Bourke Street Mall (North)     1299.125000  1303.541667
# Flinders St-Spark La            105.333333   135.250000
# QV Market-Elizabeth St (West)   633.041667   367.500000
#
# [3 rows x 362 columns]

# %%
average_transposed.to_csv("../Output/1_pedestrian_csv/censors2019_chosen3_dailyaverage_transposed.csv", encoding="utf-8", index=False, header=True)

# %%
average_transposed.describe()
# Out:
# Date     1/02/2019    1/03/2019    1/04/2019    1/05/2019    1/06/2019  \
# count     3.000000     3.000000     3.000000     3.000000     3.000000
# mean    758.694444   721.527778   644.909091   718.027778   742.430556
# std     675.913043   668.475475   583.880641   612.486829   672.554317
# min     185.708333   154.833333   138.818182   180.416667   101.375000
# 25%     385.979167   352.916667   325.500000   384.645833   392.354167
# 50%     586.250000   551.000000   512.181818   588.875000   683.333333
# 75%    1045.187500  1004.875000   897.954545   986.833333  1062.958333
# max    1504.125000  1458.750000  1283.727273  1384.791667  1442.583333
#
# Date     1/07/2019    1/08/2019    1/09/2019    1/10/2019    1/11/2019  ...  \
# count     3.000000     3.000000     3.000000     3.000000     3.000000  ...
# mean    610.763889   714.777778   588.069444   790.550725   778.013889  ...
# std     605.552942   616.771261   513.983397   705.098961   699.013553  ...
# min     147.750000   143.000000    77.041667   162.478261   158.708333  ...
# 25%     268.125000   387.979167   329.625000   409.195652   399.041667  ...
# 50%     388.500000   632.958333   582.208333   655.913043   639.375000  ...
# 75%     842.270833  1000.666667   843.583333  1104.586957  1087.666667  ...
# max    1296.041667  1368.375000  1104.958333  1553.260870  1535.958333  ...
#
# Date     9/03/2019    9/04/2019    9/05/2019    9/06/2019    9/07/2019  \
# count     3.000000     3.000000     3.000000     3.000000     3.000000
# mean    816.416667   720.986111   698.277778   728.611111   680.388889
# std     707.151627   592.601436   616.251271   614.501854   484.742444
# min     134.166667   181.666667   148.958333   111.083333   184.291667
# 25%     451.583333   403.791667   365.083333   422.895833   444.125000
# 50%     769.000000   625.916667   581.208333   734.708333   703.958333
# 75%    1157.541667   990.645833   972.937500  1037.375000   928.437500
# max    1546.083333  1355.375000  1364.666667  1340.041667  1152.916667
#
# Date     9/08/2019    9/09/2019    9/10/2019    9/11/2019    9/12/2019
# count     3.000000     3.000000     3.000000     3.000000     3.000000
# mean    718.305556   550.222222   677.916667   679.166667   602.097222
# std     660.959042   520.479904   584.735054   598.230953   618.468469
# min     138.791667   133.625000   146.083333   105.333333   135.250000
# 25%     358.375000   258.500000   364.833333   369.187500   251.375000
# 50%     577.958333   383.375000   583.583333   633.041667   367.500000
# 75%    1008.062500   758.520833   943.833333   966.083333   835.520833
# max    1438.166667  1133.666667  1304.083333  1299.125000  1303.541667
#
# [8 rows x 362 columns]
