# %%
import pandas as pd
from sodapy import Socrata

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.melbourne.vic.gov.au", None)

MyAppToken = "95TJNF2CEl6aUWA4cHIZFJzsw"

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.melbourne.vic.gov.au",
               MyAppToken,
               username="nkoleits@gmail.com",
               password="")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("xt2y-tnn9", limit=80000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.head()
# Out:
#   census_year block_id property_id base_property_id  \
# 0        2002      203      109358           109358
# 1        2002      204      101613           101613
# 2        2002      205      104469           104469
# 3        2002      206      103691           103691
# 4        2002      206      103691           103691
#
#                          street_address clue_small_area  \
# 0  832-834 Swanston Street CARLTON 3053         Carlton
# 1  377-391 Cardigan Street CARLTON 3053         Carlton
# 2   114-152 Grattan Street CARLTON 3053         Carlton
# 3   221-229 Faraday Street CARLTON 3053         Carlton
# 4   221-229 Faraday Street CARLTON 3053         Carlton
#
#                          trading_name industry_anzsic4_code  \
# 0                             Unibite                  4512
# 1                         Clyde Hotel                  4520
# 2  Royal Women's Hospital Coffee Shop                  4512
# 3             Thresherman's Bakehouse                  4511
# ...

# %%
results_df.dtypes
# Out:
# census_year                     object
# block_id                        object
# property_id                     object
# base_property_id                object
# street_address                  object
# clue_small_area                 object
# trading_name                    object
# industry_anzsic4_code           object
# industry_anzsic4_description    object
# seating_type                    object
# number_of_seats                 object
# x_coordinate                    object
# y_coordinate                    object
# geocoded_column                 object
# dtype: object

# %%
results_df['census_year'] = pd.to_numeric(results_df['census_year'])

# %%
results_df[results_df['census_year'] > 2018]
# Out:
#        census_year block_id property_id base_property_id  \
# 47120         2019      203      103123           103123
# 47121         2019      203      103123           103123
# 47122         2019      203      109358           109358
# 47123         2019      204      101613           101613
# 47124         2019      204      101613           101613
# ...            ...      ...         ...              ...
# 50647         2019      861      102507           102507
# 50648         2019      862      102498           102498
# 50649         2019      862      102498           102498
# 50650         2019      862      109532           109532
# 50651         2019      862      109532           109532
#
#                                  street_address clue_small_area  \
# 47120             258 Elgin Street CARLTON 3053         Carlton
# 47121             258 Elgin Street CARLTON 3053         Carlton
# 47122      832-834 Swanston Street CARLTON 3053         Carlton
# ...
