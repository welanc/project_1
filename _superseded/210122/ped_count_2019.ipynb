# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json

# %%
# Pull the data from the csv
ped_count_df = pd.read_csv("Resource/COM_ftraffic_2019_select4.csv")
# Change the -ve values to 0
ped_num_df = ped_count_df._get_numeric_data()
ped_num_df[ped_num_df < 0] = 0
# Convert the date into a datetime for easy sorting
ped_count_df['Date'] = pd.to_datetime(ped_count_df['Date'])
ped_count_df
# Out:
#            Date  Hour  Bourke Street Mall (North)  QV Market-Peel St  \
# 0    2019-01-01     0                         918                137
# 1    2019-01-01     1                         995                165
# 2    2019-01-01     2                         416                 72
# 3    2019-01-01     3                         382                 34
# 4    2019-01-01     4                         165                 23
# ...         ...   ...                         ...                ...
# 8755 2019-12-31    19                        2276                124
# 8756 2019-12-31    20                        1993                144
# 8757 2019-12-31    21                        1537                101
# 8758 2019-12-31    22                        1607                136
# 8759 2019-12-31    23                         732                192
#
#       Flinders St-Spring St (West)  QVM-Franklin St (North)
# 0                              617                      446
# ...

# %%
# Get the daily average pedestrian count
averagePed_df = ped_count_df.groupby('Date')[['Bourke Street Mall (North)', 'QV Market-Peel St', 'Flinders St-Spring St (West)', 'QVM-Franklin St (North)']].mean()
averagePed_df
# Out:
#             Bourke Street Mall (North)  QV Market-Peel St  \
# Date
# 2019-01-01                 1119.375000          74.916667
# 2019-01-02                 1504.125000         142.541667
# 2019-01-03                 1458.750000         122.833333
# 2019-01-04                 1178.708333         107.833333
# 2019-01-05                 1384.791667         130.375000
# ...                                ...                ...
# 2019-12-27                 1779.791667         136.375000
# 2019-12-28                 1514.125000         149.750000
# 2019-12-29                 1380.291667         140.458333
# 2019-12-30                 1056.000000          65.291667
# 2019-12-31                 1589.916667         163.500000
#
#             Flinders St-Spring St (West)  QVM-Franklin St (North)
# Date
# 2019-01-01                     99.875000               105.875000
# 2019-01-02                    221.041667               133.000000
# ...

# %%
# Transpose the data ready to merge to the Zomato data
averagePed_df_transposed = averagePed_df.T
averagePed_df_transposed
# Out:
# Date                           2019-01-01   2019-01-02   2019-01-03  \
# Bourke Street Mall (North)    1119.375000  1504.125000  1458.750000
# QV Market-Peel St               74.916667   142.541667   122.833333
# Flinders St-Spring St (West)    99.875000   221.041667   200.458333
# QVM-Franklin St (North)        105.875000   133.000000   143.916667
#
# Date                           2019-01-04   2019-01-05   2019-01-06  \
# Bourke Street Mall (North)    1178.708333  1384.791667  1442.583333
# QV Market-Peel St              107.833333   130.375000   164.708333
# Flinders St-Spring St (West)   195.541667   226.083333    99.375000
# QVM-Franklin St (North)        138.958333   156.875000   138.250000
#
# Date                           2019-01-07   2019-01-08   2019-01-09  \
# Bourke Street Mall (North)    1296.041667  1368.375000  1104.958333
# QV Market-Peel St                0.000000   129.916667   160.708333
# Flinders St-Spring St (West)   188.750000   189.166667    50.291667
# ...
