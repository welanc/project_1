# %%
# Include this line to make plots interactive
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import json
import collections

# %%
# pulling the data from the csv file 
zomato_df = pd.read_csv("Output/csv/Zomato_Restaurants_All_Consolidated-Types.csv")
zomato_df
# Out:
#      Unnamed: 0                       Name  Aggregate Rating        Type  \
# 0            10              Hungry Jack's               3.2   Fast Food
# 1            11                 Udon Yasan               4.0  Restaurant
# 2            12                     Heroes               3.0  Restaurant
# 3            13               Tiger Tea 虎將               3.4   Beverages
# 4            14    Two Peck Crispy Chicken               3.4  Restaurant
# ..          ...                        ...               ...         ...
# 394         534   Narocha Premium Tea Room               4.1   Beverages
# 395         535             Simply Spanish               3.9  Restaurant
# 396         537               NeNe Chicken               3.2  Restaurant
# 397         538        Andrew's Bread Shop               3.7      Bakery
# 398         539  Ferguson Plarre Bakehouse               3.6   Fast Food
#
#      Price   Latitude   Longitude  Sensor ID                       Sensor
# 0        2 -37.812758  144.967896         21  Bourke St-Russell St (West)
# 1        2 -37.812772  144.967762         21  Bourke St-Russell St (West)
# 2        3 -37.812770  144.967708         21  Bourke St-Russell St (West)
# 3        1 -37.812596  144.967410         21  Bourke St-Russell St (West)
# 4        1 -37.812487  144.967358         21  Bourke St-Russell St (West)
# ..     ...        ...         ...        ...                          ...
# 394      1 -37.807102  144.960176         51      QVM-Franklin St (North)
# 395      3 -37.806895  144.959613         51      QVM-Franklin St (North)
# 396      2 -37.809013  144.960929         51      QVM-Franklin St (North)
# 397      1 -37.806817  144.959129         51      QVM-Franklin St (North)
# 398      1 -37.806789  144.959164         51      QVM-Franklin St (North)
#
# [399 rows x 9 columns]

# %%
zomato_df.count()
# Out:
# Unnamed: 0          399
# Name                399
# Aggregate Rating    399
# Type                399
# Price               399
# Latitude            399
# Longitude           399
# Sensor ID           399
# Sensor              399
# dtype: int64

# %%
zomato_df.dtypes
# Out:
# Unnamed: 0            int64
# Name                 object
# Aggregate Rating    float64
# Type                 object
# Price                 int64
# Latitude            float64
# Longitude           float64
# Sensor ID             int64
# Sensor               object
# dtype: object

# %%
location_df = pd.read_csv("Output/csv/sensor_locs_final_9.csv")
location_df
# Out:
#                          Location  Daily Average
# 0                Town Hall (West)    1448.107093
# 1   Spencer St-Collins St (North)    1406.290151
# 2                       Southbank    1251.470469
# 3              Collins St (North)     719.771243
# 4     Bourke St-Russell St (West)     665.944904
# 5  Chinatown-Lt Bourke St (South)     424.210388
# 6            Flinders St-Spark La     147.414485
# 7         QVM-Franklin St (North)     132.538986
# 8                 Lygon St (East)     144.742824

# %%
location_df = location_df.set_index("Location").sort_index()
location_df
# Out:
#                                 Daily Average
# Location
# Bourke St-Russell St (West)        665.944904
# Chinatown-Lt Bourke St (South)     424.210388
# Collins St (North)                 719.771243
# Flinders St-Spark La               147.414485
# Lygon St (East)                    144.742824
# QVM-Franklin St (North)            132.538986
# Southbank                         1251.470469
# Spencer St-Collins St (North)     1406.290151
# Town Hall (West)                  1448.107093

# %%
location_df = location_df.rename(index={"Collins St (North)":"Collins Street (North)"})
location_df
# Out:
#                                 Daily Average
# Location
# Bourke St-Russell St (West)        665.944904
# Chinatown-Lt Bourke St (South)     424.210388
# Collins Street (North)             719.771243
# Flinders St-Spark La               147.414485
# Lygon St (East)                    144.742824
# QVM-Franklin St (North)            132.538986
# Southbank                         1251.470469
# Spencer St-Collins St (North)     1406.290151
# Town Hall (West)                  1448.107093

# %%
big_merge_df = pd.merge(zomato_df,location_df,left_on="Sensor",right_index=True,how="outer")
big_merge_df
# Out:
#      Unnamed: 0                       Name  Aggregate Rating        Type  \
# 0            10              Hungry Jack's               3.2   Fast Food
# 1            11                 Udon Yasan               4.0  Restaurant
# 2            12                     Heroes               3.0  Restaurant
# 3            13               Tiger Tea 虎將               3.4   Beverages
# 4            14    Two Peck Crispy Chicken               3.4  Restaurant
# ..          ...                        ...               ...         ...
# 394         534   Narocha Premium Tea Room               4.1   Beverages
# 395         535             Simply Spanish               3.9  Restaurant
# 396         537               NeNe Chicken               3.2  Restaurant
# 397         538        Andrew's Bread Shop               3.7      Bakery
# 398         539  Ferguson Plarre Bakehouse               3.6   Fast Food
#
#      Price   Latitude   Longitude  Sensor ID                       Sensor  \
# 0        2 -37.812758  144.967896         21  Bourke St-Russell St (West)
# 1        2 -37.812772  144.967762         21  Bourke St-Russell St (West)
# 2        3 -37.812770  144.967708         21  Bourke St-Russell St (West)
# 3        1 -37.812596  144.967410         21  Bourke St-Russell St (West)
# 4        1 -37.812487  144.967358         21  Bourke St-Russell St (West)
# ..     ...        ...         ...        ...                          ...
# 394      1 -37.807102  144.960176         51      QVM-Franklin St (North)
# 395      3 -37.806895  144.959613         51      QVM-Franklin St (North)
# 396      2 -37.809013  144.960929         51      QVM-Franklin St (North)
# 397      1 -37.806817  144.959129         51      QVM-Franklin St (North)
# 398      1 -37.806789  144.959164         51      QVM-Franklin St (North)
#
#      Daily Average
# 0       665.944904
# 1       665.944904
# 2       665.944904
# 3       665.944904
# 4       665.944904
# ..             ...
# 394     132.538986
# 395     132.538986
# 396     132.538986
# 397     132.538986
# 398     132.538986
#
# [399 rows x 10 columns]

# %%
#scatter plot by rating
foot_traffic_big = big_merge_df["Daily Average"]
rating_big = big_merge_df["Aggregate Rating"]
price_big = big_merge_df["Price"]

# %%
rate_b_slope, rate_b_int, rate_b_r, rate_b_p, rate_b_std_err = stats.linregress(foot_traffic_big, rating_big)
rate_b_fit = rate_b_slope * foot_traffic_big + rate_b_int
plt.scatter(foot_traffic_big, rating_big, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)
plt.xlabel("Daily Average Pedestrian Count")
plt.ylabel("Aggregate User Rating")
plt.plot(foot_traffic_big,rate_b_fit,"--")
plt.show()
print(f"r value = {rate_b_r}")
print(f"r squared = {rate_b_r**2}")
# Out:
# r value = -0.2091248070129055
# r squared = 0.04373318490818497

# %%
price_slope, price_int, price_r, price_p, price_std_err = stats.linregress(foot_traffic_big, price_big)
price_fit = price_slope * foot_traffic_big + price_int
plt.scatter(foot_traffic_big, price_big, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)
plt.xlabel("Daily Average Pedestrian Count")
plt.ylabel("Price Rating")
plt.plot(foot_traffic_big,price_fit,"--")
plt.show()
print(f"r value = {price_r}")
print(f"r squared = {price_r**2}")
# Out:
# r value = -0.07989640303946756
# r squared = 0.006383435218645041

# %%
# grouping by the date and applying aggregates
grouped = zomato_df.groupby(["Sensor"])
averages_df = grouped[['Aggregate Rating','Price']].mean()
averages_df.head()
# Out:
#                                 Aggregate Rating     Price
# Sensor
# Bourke St-Russell St (West)             3.721053  2.342105
# Chinatown-Lt Bourke St (South)          3.635897  2.897436
# Collins Street (North)                  3.492593  2.592593
# Flinders St-Spark La                    3.759184  2.836735
# Lygon St (East)                         3.372414  2.775862

# %%
merge_df = pd.merge(averages_df,location_df, left_index=True, right_index=True, how="outer")
merge_df
# Out:
#                                 Aggregate Rating     Price  Daily Average
# Sensor
# Bourke St-Russell St (West)             3.721053  2.342105     665.944904
# Chinatown-Lt Bourke St (South)          3.635897  2.897436     424.210388
# Collins Street (North)                  3.492593  2.592593     719.771243
# Flinders St-Spark La                    3.759184  2.836735     147.414485
# Lygon St (East)                         3.372414  2.775862     144.742824
# QVM-Franklin St (North)                 3.790741  1.962963     132.538986
# Southbank                               3.460714  2.857143    1251.470469
# Spencer St-Collins St (North)           2.823077  2.076923    1406.290151
# Town Hall (West)                        3.261538  2.153846    1448.107093

# %%
merge_df.to_csv("Output/csv/combined_sensor_rating_price_traffic.csv")

# %%
merge_df.dtypes
# Out:
# Aggregate Rating    float64
# Price               float64
# Daily Average       float64
# dtype: object

# %%
merge_df = merge_df.reset_index()

# %%
merge_df = merge_df.sort_values(by="Daily Average", ascending=False)
merge_df
# Out:
#                            Sensor  Aggregate Rating     Price  Daily Average
# 8                Town Hall (West)          3.261538  2.153846    1448.107093
# 7   Spencer St-Collins St (North)          2.823077  2.076923    1406.290151
# 6                       Southbank          3.460714  2.857143    1251.470469
# 2          Collins Street (North)          3.492593  2.592593     719.771243
# 0     Bourke St-Russell St (West)          3.721053  2.342105     665.944904
# 1  Chinatown-Lt Bourke St (South)          3.635897  2.897436     424.210388
# 3            Flinders St-Spark La          3.759184  2.836735     147.414485
# 4                 Lygon St (East)          3.372414  2.775862     144.742824
# 5         QVM-Franklin St (North)          3.790741  1.962963     132.538986

# %%
foot_traffic = merge_df["Daily Average"]
rating = merge_df["Aggregate Rating"]
locations = merge_df["Sensor"]
price = merge_df["Price"]

# %%
# linear regression
rate_slope, rate_int, rate_r, rate_p, rate_std_err = stats.linregress(foot_traffic, rating)
rate_fit = rate_slope * foot_traffic + rate_int

# scatter plot by rating
plt.scatter(foot_traffic, rating, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)
plt.xlabel("Daily Average Pedestrian Count")
plt.ylabel("Averaged Aggregate User Rating")
plt.plot(foot_traffic,rate_fit,"--")
plt.show()
print(f"r value = {rate_r}")
print(f"r squared = {rate_r**2}")
# Out:
# r value = -0.7199004463409644
# r squared = 0.5182566526419198

# %%
# linear regression
price_slope, price_int, price_r, price_p, price_std_err = stats.linregress(foot_traffic, price)
price_fit = price_slope * foot_traffic_big + price_int

# scatter plot by price
plt.scatter(foot_traffic, price, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)
plt.xlabel("Daily Average Pedestrian Count")
plt.ylabel("Averaged Price Rating")
plt.plot(foot_traffic_big,price_fit,"--")
plt.show()
print(f"r value = {price_r}")
print(f"r squared = {price_r**2}")
# Out:
# r value = -0.30847646422616165
# r squared = 0.09515772898147438

# %%
# Create a bar chart based upon the above data
plt.bar(locations, rating, color="b", align="center")

plt.title("Average restaurant rating in locations")
plt.xlabel("City location")
plt.ylabel("Average restaurant rating")
plt.xticks(locations, rotation=90)
# plt.figure(figsize=(10,10))
# plt.tight_layout()
#plt.savefig("../Output/barchart_avpricein3locations.png")
plt.show()

# %%
# Create a bar chart based upon the above data
plt.bar(locations, price, color="b", align="center")

plt.title("Average restaurant price in locations")
plt.xlabel("City location")
plt.ylabel("Average restaurant price")
plt.xticks(locations, rotation=90)
# plt.figure(figsize=(10,10))
# plt.tight_layout()
#plt.savefig("../Output/barchart_avpricein3locations.png")
plt.show()

# %%
loc_list = merge_df["Sensor"].tolist()
loc_list
# Out:
# ['Town Hall (West)',
#  'Spencer St-Collins St (North)',
#  'Southbank',
#  'Collins Street (North)',
#  'Bourke St-Russell St (West)',
#  'Chinatown-Lt Bourke St (South)',
#  'Flinders St-Spark La',
#  'Lygon St (East)',
#  'QVM-Franklin St (North)']

# %%
a_dict = {}
# a_dict["a"].append("hello")

for location in loc_list:
#     print(location)
    if location in a_dict:
        a_dict[location].append(zomato_df.loc[zomato_df["Sensor"] == location,:].groupby(["Type"])["Name"].count().to_dict())
    else:
        a_dict[location] = zomato_df.loc[zomato_df["Sensor"] == location,:].groupby(["Type"])["Name"].count().to_dict()
    #a_dict[location].append(zomato_df.loc[zomato_df["Sensor"] == location,:].groupby(["Type"])["Name"].count().to_dict())

# %%
a_locs = pd.DataFrame(a_dict)
type_locs = a_locs.T
type_locs
# Out:
#                                 Bakery  Bar  Beverages  Cafe  Restaurant  \
# Town Hall (West)                   1.0  2.0        4.0   6.0        13.0
# Spencer St-Collins St (North)      2.0  4.0        3.0  13.0        19.0
# Southbank                          NaN  4.0        1.0   9.0        31.0
# Collins Street (North)             1.0  1.0        1.0  14.0         6.0
# Bourke St-Russell St (West)        1.0  NaN        3.0   1.0        28.0
# Chinatown-Lt Bourke St (South)     NaN  5.0        2.0   1.0        30.0
# Flinders St-Spark La               1.0  4.0        2.0  16.0        21.0
# Lygon St (East)                    NaN  3.0        3.0   7.0        40.0
# QVM-Franklin St (North)            4.0  2.0        7.0   6.0        21.0
#
#                                 Desserts  Fast Food  Pub
# Town Hall (West)                     NaN        NaN  NaN
# Spencer St-Collins St (North)        2.0        8.0  1.0
# Southbank                            3.0        7.0  1.0
# Collins Street (North)               1.0        2.0  1.0
# Bourke St-Russell St (West)          2.0        3.0  NaN
# Chinatown-Lt Bourke St (South)       1.0        NaN  NaN
# Flinders St-Spark La                 2.0        3.0  NaN
# Lygon St (East)                      4.0        1.0  NaN
# QVM-Franklin St (North)              6.0        7.0  1.0

# %%
types_merge = pd.merge(location_df, type_locs, left_index=True, right_index=True, how="outer")
types_merge
# Out:
#                                 Daily Average  Bakery  Bar  Beverages  Cafe  \
# Bourke St-Russell St (West)        665.944904     1.0  NaN        3.0   1.0
# Chinatown-Lt Bourke St (South)     424.210388     NaN  5.0        2.0   1.0
# Collins Street (North)             719.771243     1.0  1.0        1.0  14.0
# Flinders St-Spark La               147.414485     1.0  4.0        2.0  16.0
# Lygon St (East)                    144.742824     NaN  3.0        3.0   7.0
# QVM-Franklin St (North)            132.538986     4.0  2.0        7.0   6.0
# Southbank                         1251.470469     NaN  4.0        1.0   9.0
# Spencer St-Collins St (North)     1406.290151     2.0  4.0        3.0  13.0
# Town Hall (West)                  1448.107093     1.0  2.0        4.0   6.0
#
#                                 Restaurant  Desserts  Fast Food  Pub
# Bourke St-Russell St (West)           28.0       2.0        3.0  NaN
# Chinatown-Lt Bourke St (South)        30.0       1.0        NaN  NaN
# Collins Street (North)                 6.0       1.0        2.0  1.0
# Flinders St-Spark La                  21.0       2.0        3.0  NaN
# Lygon St (East)                       40.0       4.0        1.0  NaN
# QVM-Franklin St (North)               21.0       6.0        7.0  1.0
# Southbank                             31.0       3.0        7.0  1.0
# Spencer St-Collins St (North)         19.0       2.0        8.0  1.0
# Town Hall (West)                      13.0       NaN        NaN  NaN

# %%
count=1
plt.subplots(figsize=(10, 8))
for i in type_locs.columns:
    #plt.subplot(3,2,count)
    plt.scatter(types_merge["Daily Average"],types_merge[i])
    plt.legend(type_locs.columns)
    count+=1

plt.show()

# %%
# locations = averages_df["Sensor"]
# footfall = averages_df["Yearly Average Ped Count"]
# # Create a bar chart based upon the above data
# plt.bar(locations, footfall, color="deeppink", align="center")
# plt.title("Average yearly pedestrian count in locations")
# plt.xlabel("City location")
# plt.ylabel("Average yearly pedestrian count")
# plt.xticks(locations, rotation=45)
# # plt.figure(figsize=(10,10))
# # plt.tight_layout()
# plt.savefig("../Output/barchart_yearlyavpedcountin3locations.png")
# plt.show()

# %%
# locations = averages_df["Sensor"]
# rating = averages_df["Aggregate Rating"]
# # Create a bar chart based upon the above data
# plt.bar(locations, rating, color="b", align="center")
# plt.title("Average restaurant rating in locations")
# plt.xlabel("City location")
# plt.ylabel("Average restaurant rating")
# plt.xticks(locations, rotation=45)
# # plt.figure(figsize=(10,10))
# # plt.tight_layout()
# plt.savefig("../Output/barchart_avratingin3locations.png")
# plt.show()

# %%
# ratingprice_df = averages_df.loc[:,["Sensor","Aggregate Rating", "Price"]]
# ratingprice_df

# %%
# ratingprice_df = ratingprice_df.set_index("Sensor")
# ratingprice_df

# %%
# # Create a bar chart based off of the group series from before
# count_chart = ratingprice_df.plot(kind='bar',rot=30,fontsize=11, figsize=(15,10), grid=True)
# # Set the xlabel and ylabel using class methods
# count_chart.set_xlabel("Sensor Locations", fontsize=14)
# count_chart.set_ylabel("Rating and price score out of 5",fontsize=14)
# count_chart.set_title("Rating and price comparison for 3 sensor locations", fontsize=16)
# plt.tight_layout()
# count_chart.get_figure()
# count_chart.figure.savefig("../Output/bar_compareratingprice_3locations.png")
# plt.show()

# %%
# BSM busiest, flinders quietest, qvm inbetween
