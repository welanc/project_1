# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from config import gkey

# %%
df = pd.read_csv("Zomato_Restaurants_All_Consolidated-Types.csv")
df
# Out:
#      Unnamed: 0                         Name  Aggregate Rating        Type  \
# 0             0                    Soul Cafe               3.0        Cafe
# 1             1                     Song Tea               3.5   Beverages
# 2             2  Sensory Lab - Bourke Street               3.4        Cafe
# 3             3                       SamSam               4.0  Restaurant
# 4             4                  Boost Juice               3.7   Beverages
# ..          ...                          ...               ...         ...
# 100         115          The Borek Bakehouse               4.4      Bakery
# 101         116                     Chickcha               3.7        Cafe
# 102         117   Damiao Panda Fan 大妙火锅 · 川菜               3.0  Restaurant
# 103         118      Mansae Korean BBQ & Bar               4.5  Restaurant
# 104         119           The Orient Hot Pot               3.8  Restaurant
#
# ...

# %%
## Creating a heat map that displays the rating for every restaurant 

# Configure gmaps
gmaps.configure(api_key=gkey)

# Store latitude and longitude in locations
locations = df[["Latitude", "Longitude"]]

# Define rating so can set it as the weight
rating = df["Aggregate Rating"]

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Access maps with unique API key
gmaps.configure(api_key=gkey)

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Name}</dd>
<dt>Type</dt><dd>{Type}</dd>
<dt>Rating</dt><dd>{Aggregate Rating}</dd>
<dt>Price</dt><dd>{Price}</dd>
<dt>Sensor</dt><dd>{Sensor}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
eatery_info = [info_box_template.format(**row) for index, row in df.iterrows()]
locations = df[["Latitude", "Longitude"]]

# %%
# Assign the marker layer to a variable
markers = gmaps.marker_layer(locations, info_box_content=eatery_info)

# Plot Heatmap
fig = gmaps.figure()

# Add marker layer ontop of heat map
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
melb_df = pd.read_csv("Melb_City_Restaurants.csv")
melb_df
# Out:
#     Unnamed: 0                      Name     Seating Type  \
# 0            0                 Soul Cafe   Seats - Indoor
# 1            2            Hotel Swanston   Seats - Indoor
# 2            3      Yoyogi Japanese Cafe  Seats - Outdoor
# 3            5         Crown Cafe Bakery   Seats - Indoor
# 4            7  Starbucks Coffee Company   Seats - Indoor
# ..         ...                       ...              ...
# 81         587           Felt Restaurant   Seats - Indoor
# 82         609                     Verge   Seats - Indoor
# 83         611          Verge Restuarant   Seats - Indoor
# 84         635                 Nama Nama   Seats - Indoor
# 85         641                     Kappo   Seats - Indoor
#
#                      Type  Latitude  Longitude
# 0   Cafes and Restaurants  -37.8131   144.9650
# 1           Accommodation  -37.8131   144.9650
# 2   Cafes and Restaurants  -37.8128   144.9650
# 3   Cafes and Restaurants  -37.8128   144.9650
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Name}</dd>
<dt>Type</dt><dd>{Type}</dd>
<dt>Rating</dt><dd>{Aggregate Rating}</dd>
<dt>Price</dt><dd>{Price}</dd>
<dt>Sensor</dt><dd>{Sensor}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
m_eatery_info = [info_box_template.format(**row) for index, row in df.iterrows()]
m_locations = melb_df[["Latitude", "Longitude"]]

# %%
# Assign the marker layer to a variable
markers = gmaps.marker_layer(locations, info_box_content=eatery_info)

# Plot Heatmap
fig = gmaps.figure()

# Add marker layer ontop of heat map
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
